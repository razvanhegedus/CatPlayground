# %%
import fiftyone as fo

# Check if it exists, then load it; otherwise, create it
if fo.dataset_exists("cat-dataset-cropped"):
    dataset = fo.load_dataset("cat-dataset-cropped")
else:
    dataset = fo.Dataset.from_dir(
        dataset_dir="dataset/crop",
        dataset_type=fo.types.ImageDirectory,
        name="cat-dataset-cropped"
    )

session = fo.launch_app(dataset, auto=False)
print(session.url)
# Out:
#  100% |███████████████| 6197/6197 [270.3ms elapsed, 0s remaining, 22.9K samples/s]
# Session launched. Run `session.show()` to open the App in a cell output.
# http://localhost:5151/
