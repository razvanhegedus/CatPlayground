# %%
from pathlib import Path
from PIL import Image
import numpy as np
# Out:
# Running cells with 'cpython-3.14.4-macos-aarch64-none (3.14.4) (Python 3.14.4)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/Users/hegedusrazvan/.local/share/uv/python/cpython-3.14.4-macos-aarch64-none/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
dataset_path = Path("/Users/hegedusrazvan/Developer/Faculty/IOTCA/CatPlayground/dataset/images")
images = dataset_path.glob("*.png")
image_path = sorted([img for img in images], key=lambda x: x.name)[0]

img = Image.open(image_path)
img_np = np.asarray(img)
print(img.size)

img_crop = Image.fromarray(img_np[80:, 384:, :])
print(img_crop.size)
display(img_crop)
# Out:
# (1280, 720)
# 2764800
# (896, 640)
# <PIL.Image.Image image mode=RGB size=896x640>
